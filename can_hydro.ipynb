# %% [markdown]
# # Part I: Importing Libraries and retrieval/download of files from GovCanada webpage
#
# * *Part I running time: ~20 mins*

# %% [markdown]
# ##  Import libraries

# %%
# Data analysis 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Plotly libraries
import fastparquet
import pyarrow

# Web scraping and file retrieval
import os
import glob
import datetime

# Database processing
import sqlite3
import dask.dataframe as dd

# Visualization and geo-data imports
import geopandas as gpd
import chart_studio.plotly as py
import plotly.graph_objects as go

# Offline mode
import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)

# Hyperlink / Web display
from IPython.core.display import display, HTML

# Formatting options
pd.options.display.float_format = '{:,.3f}'.format
np.set_printoptions(precision=2)

print('Library imports complete!')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# Library imports complete!

# %% [markdown]
# ## Download Hydrometric Station Location data from Hydat.sqlite3 database
#
# * *Select STATIONS where HYD_STATUS = A (Active)*
# * *Ignore STATIONS where HYD_STATUS = D (Deactivated/Inactive)*
# * *Export the database table to a .csv file*
# * *Check the file DataFrame file to see that it works!*
# * *Close the connection*

# %%
os.chdir(r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/sqlite3')

# Create connection to Hydat database
con = sqlite3.connect("Hydat.sqlite3")
cursor = con.cursor()

#all_database_stuff = cursor.execute("SELECT * FROM sqlite_master").fetchall()
df_stations = pd.read_sql_query('SELECT * from STATIONS where HYD_STATUS = "A"', con) #A = active stations

# Verify that result of SQL query is stored in the dataframe
df_stations.rename(columns={df_stations.columns[0]: "ID"}, inplace=True)
df_stations.rename(columns={df_stations.columns[2]: "PROV_TERR"}, inplace=True)
df_stations.rename(columns={df_stations.columns[8]: "DRAINAGE_AREA_GROSS_KM2"}, inplace=True)

df_stations['PROV_TERR_ID'] = df_stations['PROV_TERR'] + df_stations['ID']

# Drop extra columns 
df_stations.drop(df_stations.loc[:, 'DRAINAGE_AREA_EFFECT': 'DATUM_ID'], inplace=True, axis=1)
df_stations.drop(labels = ['SED_STATUS'], inplace = True, axis = 1)

print(df_stations.info())

df_stations.to_csv('Hydat.csv')

# Close the connection
con.close()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2786 entries, 0 to 2785
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       2786 non-null   object
#  1   STATION_NAME             2786 non-null   object
#  2   PROV_TERR                2786 non-null   object
#  3   REGIONAL_OFFICE_ID       2786 non-null   object
#  4   HYD_STATUS               2786 non-null   object
#  5   LATITUDE                 2786 non-null   float64
#  6   LONGITUDE                2786 non-null   float64
#  7   DRAINAGE_AREA_GROSS_KM2  2406 non-null   float64
#  8   PROV_TERR_ID             2786 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 196.0+ KB
# None

# %% [markdown]
# ## Download multiple .csv files from Hydrometric .url directory using wget
#
# * *Hyperlink:* <a href="https://dd.weather.gc.ca/hydrometric/csv/">[https://dd.weather.gc.ca/hydrometric/csv/](https://dd.weather.gc.ca/hydrometric/csv/)</a>
#
# * *Downloading time: ~4 mins*
#
# * *All provincial files for download:*
#
#     "AB_daily_hydrometric.csv, BC_daily_hydrometric.csv, SK_daily_hydrometric.csv, /
#     MB_daily_hydrometric.csv, ON_daily_hydrometric.csv, QC_daily_hydrometric.csv, /
#     NB_daily_hydrometric.csv, NS_daily_hydrometric.csv, PE_daily_hydrometric.csv, /
#     NL_daily_hydrometric.csv, NT_daily_hydrometric.csv, NU_daily_hydrometric.csv, /
#     YT_daily_hydrometric.csv"

# %%
os.chdir(r"C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily")

# Download hydrometric daily sub directories fast:
# !wget --wait=2 -r -np -nH -nd -e robots=off --cut-dirs=3 --reject "index.html*" --accept "AB_daily_hydrometric.csv, BC_daily_hydrometric.csv, SK_daily_hydrometric.csv, MB_daily_hydrometric.csv, ON_daily_hydrometric.csv, QC_daily_hydrometric.csv, NB_daily_hydrometric.csv, NS_daily_hydrometric.csv, PE_daily_hydrometric.csv, NL_daily_hydrometric.csv, NT_daily_hydrometric.csv, NU_daily_hydrometric.csv, YT_daily_hydrometric.csv" https://dd.weather.gc.ca/hydrometric/csv/ --no-check-certificate
    
# Template for file downloads
"""
"AB_daily_hydrometric.csv, BC_daily_hydrometric.csv, SK_daily_hydrometric.csv, /
MB_daily_hydrometric.csv, ON_daily_hydrometric.csv, QC_daily_hydrometric.csv, /
NB_daily_hydrometric.csv, NS_daily_hydrometric.csv, PE_daily_hydrometric.csv, /
NL_daily_hydrometric.csv, NT_daily_hydrometric.csv, NU_daily_hydrometric.csv, /
YT_daily_hydrometric.csv"

"""
print("Completed downloads!")
# Out:
# Completed downloads!
# --2022-01-23 20:50:43--  https://dd.weather.gc.ca/hydrometric/csv/
# Resolving dd.weather.gc.ca (dd.weather.gc.ca)... 205.189.10.47
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1935 (1.9K) [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .                                                     100% 33.0M=0s
#
# 2022-01-23 20:50:44 (33.0 MB/s) - 'index.html.tmp' saved [1935/1935]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:50:46--  https://dd.weather.gc.ca/hydrometric/csv/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:50:48--  https://dd.weather.gc.ca/hydrometric/csv/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1935 (1.9K) [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K .                                                     100% 15.7M=0s
#
# 2022-01-23 20:50:48 (15.7 MB/s) - 'index.html@C=M;O=A.tmp' saved [1935/1935]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:50:50--  https://dd.weather.gc.ca/hydrometric/csv/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:50:52--  https://dd.weather.gc.ca/hydrometric/csv/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1935 (1.9K) [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K .                                                     100% 33.6M=0s
#
# 2022-01-23 20:50:52 (33.6 MB/s) - 'index.html@C=D;O=A.tmp' saved [1935/1935]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:50:54--  https://dd.weather.gc.ca/hydrometric/csv/AB/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 24.8M=0s
#
# 2022-01-23 20:50:54 (24.8 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:50:56--  https://dd.weather.gc.ca/hydrometric/csv/BC/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 18.3M=0s
#
# 2022-01-23 20:50:57 (18.3 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:50:59--  https://dd.weather.gc.ca/hydrometric/csv/MB/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 16.9M=0s
#
# 2022-01-23 20:50:59 (16.9 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:01--  https://dd.weather.gc.ca/hydrometric/csv/NB/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:51:03--  https://dd.weather.gc.ca/hydrometric/csv/NL/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 13.1M=0s
#
# 2022-01-23 20:51:03 (13.1 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:05--  https://dd.weather.gc.ca/hydrometric/csv/NS/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 23.4M=0s
#
# 2022-01-23 20:51:06 (23.4 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:08--  https://dd.weather.gc.ca/hydrometric/csv/NT/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 13.8M=0s
#
# 2022-01-23 20:51:08 (13.8 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:10--  https://dd.weather.gc.ca/hydrometric/csv/NU/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK

# %% [markdown]
# # Part II: Concatenate (Combine) all provincial DAILY .csv files into one DAILY .csv file
#
# * *Runtime ~4 mins*

# %%
ext = '.csv'
fnames = [i for i in glob.glob('*{}'.format(ext))]
print(fnames)
print('/n')

# Combine all files in the list and export as .csv
print('Concatenating all provincial daily hydrometric files into national file..\n')

dtypes = {" ID": str,
          "Date": str, 
          "Water Level / Niveau d'eau (m)": np.float32, 
          "Discharge / Débit (cms)": np.float32}
          
cols = list(dtypes.keys())

path = r"C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily"
df_daily = pd.concat((pd.read_csv(f, usecols=cols, dtype=dtypes, 
                                  sep=',', low_memory=False) for f in fnames))

# Cleanup new file (rename and fill N/A values)
column_indices = [0, 1, 2, 3]
new_names = ["ID", "DATE", "WATER_LEVEL_M", "FLOWRATE_CMS"]
old_names = df_daily.columns[column_indices]
df_daily.rename(columns=dict(zip(old_names, new_names)), inplace=True)

# Fill N/A values
df_daily.fillna(value='', inplace=True)

# Merge the DAILY DataFrame with the HYDRO STATION DATABASE DataFrame
df_daily = pd.merge(df_daily, df_stations, on='ID')

# Convert numeric columns to float32
cols = ["WATER_LEVEL_M", "FLOWRATE_CMS", "LATITUDE", "LONGITUDE", "DRAINAGE_AREA_GROSS_KM2"]
df_daily[cols] = pd.to_numeric(df_daily[cols].stack(), errors='coerce', downcast='float').unstack()

df_daily['STATION'] = df_daily['PROV_TERR_ID'] + "_" + df_daily['STATION_NAME']

# Replace blank spaces with _
df_daily['STATION'] = df_daily['STATION'].str.replace(' ', '_')
df_daily['STATION'] = df_daily['STATION'].str.replace('//', '_')

# Drop unneeded columns
df_daily.drop(columns=['PROV_TERR_ID', 'REGIONAL_OFFICE_ID', 'HYD_STATUS', 'STATION_NAME'], inplace=True)

df_daily.info()
# Out:
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 21.8M=0s
#
# 2022-01-23 20:51:10 (21.8 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:12--  https://dd.weather.gc.ca/hydrometric/csv/ON/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 19.1M=0s
#
# 2022-01-23 20:51:12 (19.1 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:14--  https://dd.weather.gc.ca/hydrometric/csv/PE/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 10.2M=0s
#
# 2022-01-23 20:51:15 (10.2 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:17--  https://dd.weather.gc.ca/hydrometric/csv/QC/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 23.1M=0s
#
# 2022-01-23 20:51:17 (23.1 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:19--  https://dd.weather.gc.ca/hydrometric/csv/SK/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 21.4M=0s
#
# 2022-01-23 20:51:19 (21.4 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:21--  https://dd.weather.gc.ca/hydrometric/csv/YT/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html.tmp'
#
#      0K                                                       100% 40.3M=0s
#
# 2022-01-23 20:51:21 (40.3 MB/s) - 'index.html.tmp' saved [753/753]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:23--  https://dd.weather.gc.ca/hydrometric/csv/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1935 (1.9K) [text/html]
# Saving to: 'index.html@C=N;O=A.tmp'
#
#      0K .                                                     100% 63.2M=0s
#
# 2022-01-23 20:51:24 (63.2 MB/s) - 'index.html@C=N;O=A.tmp' saved [1935/1935]
#
# Removing index.html@C=N;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:51:26--  https://dd.weather.gc.ca/hydrometric/csv/?C=M;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:51:28--  https://dd.weather.gc.ca/hydrometric/csv/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1935 (1.9K) [text/html]
# Saving to: 'index.html@C=D;O=D.tmp'
#
#      0K .                                                     100% 48.1M=0s
#
# 2022-01-23 20:51:28 (48.1 MB/s) - 'index.html@C=D;O=D.tmp' saved [1935/1935]
#
# Removing index.html@C=D;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:51:30--  https://dd.weather.gc.ca/hydrometric/csv/AB/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:51:32--  https://dd.weather.gc.ca/hydrometric/csv/AB/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 14.4M=0s
#
# 2022-01-23 20:51:32 (14.4 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:51:34--  https://dd.weather.gc.ca/hydrometric/csv/AB/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K                                                       100% 16.1M=0s
#
# 2022-01-23 20:51:35 (16.1 MB/s) - 'index.html@C=S;O=A.tmp' saved [753/753]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:51:37--  https://dd.weather.gc.ca/hydrometric/csv/AB/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 31.8M=0s
#
# 2022-01-23 20:51:37 (31.8 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:51:39--  https://dd.weather.gc.ca/hydrometric/csv/AB/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .......... .......... ..........                        536K=0.06s
#
# 2022-01-23 20:51:39 (536 KB/s) - 'index.html.tmp' saved [31438]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:41--  https://dd.weather.gc.ca/hydrometric/csv/AB/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:51:43--  https://dd.weather.gc.ca/hydrometric/csv/BC/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=N;O=D.tmp'
#
#      0K                                                       100% 30.8M=0s
#
# 2022-01-23 20:51:43 (30.8 MB/s) - 'index.html@C=N;O=D.tmp' saved [753/753]
#
# Removing index.html@C=N;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:51:46--  https://dd.weather.gc.ca/hydrometric/csv/BC/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 19.9M=0s
#
# 2022-01-23 20:51:46 (19.9 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:51:48--  https://dd.weather.gc.ca/hydrometric/csv/BC/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K                                                       100% 17.3M=0s
#
# 2022-01-23 20:51:48 (17.3 MB/s) - 'index.html@C=S;O=A.tmp' saved [753/753]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:51:50--  https://dd.weather.gc.ca/hydrometric/csv/BC/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:51:52--  https://dd.weather.gc.ca/hydrometric/csv/BC/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .......... .......... .......... .......... ..........  418K
#     50K ........                                               27.8M=0.1s
#
# 2022-01-23 20:51:53 (488 KB/s) - 'index.html.tmp' saved [59858]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:51:55--  https://dd.weather.gc.ca/hydrometric/csv/BC/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:51:57--  https://dd.weather.gc.ca/hydrometric/csv/MB/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=N;O=D.tmp'
#
#      0K                                                       100% 23.2M=0s
#
# 2022-01-23 20:51:57 (23.2 MB/s) - 'index.html@C=N;O=D.tmp' saved [753/753]
#
# Removing index.html@C=N;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:51:59--  https://dd.weather.gc.ca/hydrometric/csv/MB/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 30.7M=0s
#
# 2022-01-23 20:51:59 (30.7 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:01--  https://dd.weather.gc.ca/hydrometric/csv/MB/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K                                                       100% 21.2M=0s
#
# 2022-01-23 20:52:01 (21.2 MB/s) - 'index.html@C=S;O=A.tmp' saved [753/753]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:03--  https://dd.weather.gc.ca/hydrometric/csv/MB/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 23.7M=0s
#
# 2022-01-23 20:52:04 (23.7 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:06--  https://dd.weather.gc.ca/hydrometric/csv/MB/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:52:08--  https://dd.weather.gc.ca/hydrometric/csv/MB/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .......... .......                                      325K=0.05s
#
# 2022-01-23 20:52:08 (325 KB/s) - 'index.html.tmp' saved [17756]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:52:10--  https://dd.weather.gc.ca/hydrometric/csv/NL/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:52:12--  https://dd.weather.gc.ca/hydrometric/csv/NL/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 13.0M=0s
#
# 2022-01-23 20:52:12 (13.0 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:14--  https://dd.weather.gc.ca/hydrometric/csv/NL/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K                                                       100% 39.9M=0s
#
# 2022-01-23 20:52:15 (39.9 MB/s) - 'index.html@C=S;O=A.tmp' saved [753/753]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:17--  https://dd.weather.gc.ca/hydrometric/csv/NL/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 18.8M=0s
#
# 2022-01-23 20:52:17 (18.8 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:19--  https://dd.weather.gc.ca/hydrometric/csv/NL/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .......... .....                                        277K=0.06s
#
# 2022-01-23 20:52:19 (277 KB/s) - 'index.html.tmp' saved [15923]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:52:21--  https://dd.weather.gc.ca/hydrometric/csv/NL/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:52:23--  https://dd.weather.gc.ca/hydrometric/csv/NS/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=N;O=D.tmp'
#
#      0K                                                       100% 22.0M=0s
#
# 2022-01-23 20:52:24 (22.0 MB/s) - 'index.html@C=N;O=D.tmp' saved [753/753]
#
# Removing index.html@C=N;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:52:26--  https://dd.weather.gc.ca/hydrometric/csv/NS/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 34.5M=0s
#
# 2022-01-23 20:52:26 (34.5 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:28--  https://dd.weather.gc.ca/hydrometric/csv/NS/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K                                                       100% 16.4M=0s
#
# 2022-01-23 20:52:28 (16.4 MB/s) - 'index.html@C=S;O=A.tmp' saved [753/753]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:30--  https://dd.weather.gc.ca/hydrometric/csv/NS/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 25.1M=0s
#
# 2022-01-23 20:52:30 (25.1 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:32--  https://dd.weather.gc.ca/hydrometric/csv/NS/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5193 (5.1K) [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .....                                                 100%  123M=0s
#
# 2022-01-23 20:52:33 (123 MB/s) - 'index.html.tmp' saved [5193/5193]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:52:35--  https://dd.weather.gc.ca/hydrometric/csv/NS/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5114 (5.0K) [text/html]
# Saving to: 'index.html.tmp'
#
#      0K ....                                                  100%  116M=0s
#
# 2022-01-23 20:52:35 (116 MB/s) - 'index.html.tmp' saved [5114/5114]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:52:37--  https://dd.weather.gc.ca/hydrometric/csv/NT/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=N;O=D.tmp'
#
#      0K                                                       100% 26.2M=0s
#
# 2022-01-23 20:52:37 (26.2 MB/s) - 'index.html@C=N;O=D.tmp' saved [753/753]
#
# Removing index.html@C=N;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:52:39--  https://dd.weather.gc.ca/hydrometric/csv/NT/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 38.4M=0s
#
# 2022-01-23 20:52:39 (38.4 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:41--  https://dd.weather.gc.ca/hydrometric/csv/NT/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K                                                       100% 29.9M=0s
#
# 2022-01-23 20:52:42 (29.9 MB/s) - 'index.html@C=S;O=A.tmp' saved [753/753]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:44--  https://dd.weather.gc.ca/hydrometric/csv/NT/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 12.0M=0s
#
# 2022-01-23 20:52:44 (12.0 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:46--  https://dd.weather.gc.ca/hydrometric/csv/NT/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .......... ..                                          8.97M=0.001s
#
# 2022-01-23 20:52:46 (8.97 MB/s) - 'index.html.tmp' saved [12733]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:52:48--  https://dd.weather.gc.ca/hydrometric/csv/NT/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .......... .                                           1.47M=0.008s
#
# 2022-01-23 20:52:49 (1.47 MB/s) - 'index.html.tmp' saved [11729]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:52:51--  https://dd.weather.gc.ca/hydrometric/csv/NU/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:52:53--  https://dd.weather.gc.ca/hydrometric/csv/NU/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 26.1M=0s
#
# 2022-01-23 20:52:53 (26.1 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:55--  https://dd.weather.gc.ca/hydrometric/csv/NU/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K                                                       100% 15.3M=0s
#
# 2022-01-23 20:52:55 (15.3 MB/s) - 'index.html@C=S;O=A.tmp' saved [753/753]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:57--  https://dd.weather.gc.ca/hydrometric/csv/NU/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 22.4M=0s
#
# 2022-01-23 20:52:57 (22.4 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:52:59--  https://dd.weather.gc.ca/hydrometric/csv/NU/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3743 (3.7K) [text/html]
# Saving to: 'index.html.tmp'
#
#      0K ...                                                   100% 5.15M=0.001s
#
# 2022-01-23 20:53:00 (5.15 MB/s) - 'index.html.tmp' saved [3743/3743]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:53:02--  https://dd.weather.gc.ca/hydrometric/csv/NU/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:04--  https://dd.weather.gc.ca/hydrometric/csv/ON/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=N;O=D.tmp'
#
#      0K                                                       100% 23.9M=0s
#
# 2022-01-23 20:53:04 (23.9 MB/s) - 'index.html@C=N;O=D.tmp' saved [753/753]
#
# Removing index.html@C=N;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:53:06--  https://dd.weather.gc.ca/hydrometric/csv/ON/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 11.8M=0s
#
# 2022-01-23 20:53:06 (11.8 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:53:08--  https://dd.weather.gc.ca/hydrometric/csv/ON/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:10--  https://dd.weather.gc.ca/hydrometric/csv/ON/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 22.8M=0s
#
# 2022-01-23 20:53:10 (22.8 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:53:13--  https://dd.weather.gc.ca/hydrometric/csv/ON/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .......... .......... .......... .......... ..........  386K
#     50K .......... .......... ..                               1.50M=0.1s
#
# 2022-01-23 20:53:13 (503 KB/s) - 'index.html.tmp' saved [74213]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:53:15--  https://dd.weather.gc.ca/hydrometric/csv/ON/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:17--  https://dd.weather.gc.ca/hydrometric/csv/PE/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=N;O=D.tmp'
#
#      0K                                                       100% 5.26M=0s
#
# 2022-01-23 20:53:17 (5.26 MB/s) - 'index.html@C=N;O=D.tmp' saved [753/753]
#
# Removing index.html@C=N;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:53:19--  https://dd.weather.gc.ca/hydrometric/csv/PE/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 7.68M=0s
#
# 2022-01-23 20:53:20 (7.68 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:53:22--  https://dd.weather.gc.ca/hydrometric/csv/PE/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:24--  https://dd.weather.gc.ca/hydrometric/csv/PE/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 9.41M=0s
#
# 2022-01-23 20:53:24 (9.41 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:53:26--  https://dd.weather.gc.ca/hydrometric/csv/PE/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:28--  https://dd.weather.gc.ca/hydrometric/csv/PE/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1880 (1.8K) [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .                                                     100% 30.3M=0s
#
# 2022-01-23 20:53:28 (30.3 MB/s) - 'index.html.tmp' saved [1880/1880]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:53:30--  https://dd.weather.gc.ca/hydrometric/csv/QC/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:32--  https://dd.weather.gc.ca/hydrometric/csv/QC/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 6.13M=0s
#
# 2022-01-23 20:53:33 (6.13 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:53:35--  https://dd.weather.gc.ca/hydrometric/csv/QC/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:37--  https://dd.weather.gc.ca/hydrometric/csv/QC/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 4.51M=0s
#
# 2022-01-23 20:53:37 (4.51 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:53:39--  https://dd.weather.gc.ca/hydrometric/csv/QC/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3163 (3.1K) [text/html]
# Saving to: 'index.html.tmp'
#
#      0K ...                                                   100% 20.3M=0s
#
# 2022-01-23 20:53:39 (20.3 MB/s) - 'index.html.tmp' saved [3163/3163]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:53:41--  https://dd.weather.gc.ca/hydrometric/csv/QC/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/html]
# Saving to: 'index.html.tmp'
#
#      0K ...                                                   100% 17.7M=0s
#
# 2022-01-23 20:53:42 (17.7 MB/s) - 'index.html.tmp' saved [3203/3203]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:53:44--  https://dd.weather.gc.ca/hydrometric/csv/SK/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:46--  https://dd.weather.gc.ca/hydrometric/csv/SK/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 9.35M=0s
#
# 2022-01-23 20:53:46 (9.35 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:53:48--  https://dd.weather.gc.ca/hydrometric/csv/SK/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K                                                       100% 9.27M=0s
#
# 2022-01-23 20:53:48 (9.27 MB/s) - 'index.html@C=S;O=A.tmp' saved [753/753]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:53:50--  https://dd.weather.gc.ca/hydrometric/csv/SK/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:52--  https://dd.weather.gc.ca/hydrometric/csv/SK/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .......... .......... .                                 352K=0.06s
#
# 2022-01-23 20:53:53 (352 KB/s) - 'index.html.tmp' saved [22303]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:53:55--  https://dd.weather.gc.ca/hydrometric/csv/SK/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .......... .......... ..                                403K=0.05s
#
# 2022-01-23 20:53:55 (403 KB/s) - 'index.html.tmp' saved [22607]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:53:57--  https://dd.weather.gc.ca/hydrometric/csv/YT/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:53:59--  https://dd.weather.gc.ca/hydrometric/csv/YT/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=A.tmp'
#
#      0K                                                       100% 10.5M=0s
#
# 2022-01-23 20:53:59 (10.5 MB/s) - 'index.html@C=M;O=A.tmp' saved [753/753]
#
# Removing index.html@C=M;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:54:01--  https://dd.weather.gc.ca/hydrometric/csv/YT/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K                                                       100% 5.68M=0s
#
# 2022-01-23 20:54:02 (5.68 MB/s) - 'index.html@C=S;O=A.tmp' saved [753/753]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:54:04--  https://dd.weather.gc.ca/hydrometric/csv/YT/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=A.tmp'
#
#      0K                                                       100% 11.5M=0s
#
# 2022-01-23 20:54:04 (11.5 MB/s) - 'index.html@C=D;O=A.tmp' saved [753/753]
#
# Removing index.html@C=D;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:54:06--  https://dd.weather.gc.ca/hydrometric/csv/YT/daily/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .........                                              8.44M=0.001s
#
# 2022-01-23 20:54:06 (8.44 MB/s) - 'index.html.tmp' saved [9978]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:54:08--  https://dd.weather.gc.ca/hydrometric/csv/YT/hourly/
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html.tmp'
#
#      0K .........                                              9.03M=0.001s
#
# 2022-01-23 20:54:09 (9.03 MB/s) - 'index.html.tmp' saved [9377]
#
# Removing index.html.tmp since it should be rejected.
#
# --2022-01-23 20:54:11--  https://dd.weather.gc.ca/hydrometric/csv/AB/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=N;O=A.tmp'
#
#      0K                                                       100% 11.1M=0s
#
# 2022-01-23 20:54:11 (11.1 MB/s) - 'index.html@C=N;O=A.tmp' saved [753/753]
#
# Removing index.html@C=N;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:54:13--  https://dd.weather.gc.ca/hydrometric/csv/AB/?C=M;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=M;O=D.tmp'
#
#      0K                                                       100% 7.09M=0s
#
# 2022-01-23 20:54:13 (7.09 MB/s) - 'index.html@C=M;O=D.tmp' saved [753/753]
#
# Removing index.html@C=M;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:54:15--  https://dd.weather.gc.ca/hydrometric/csv/AB/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K                                                       100% 7.71M=0s
#
# 2022-01-23 20:54:15 (7.71 MB/s) - 'index.html@C=S;O=D.tmp' saved [753/753]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:54:17--  https://dd.weather.gc.ca/hydrometric/csv/AB/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 753 [text/html]
# Saving to: 'index.html@C=D;O=D.tmp'
#
#      0K                                                       100% 5.68M=0s
#
# 2022-01-23 20:54:18 (5.68 MB/s) - 'index.html@C=D;O=D.tmp' saved [753/753]
#
# Removing index.html@C=D;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:54:20--  https://dd.weather.gc.ca/hydrometric/csv/AB/daily/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# ['AB_daily_hydrometric.csv', 'BC_daily_hydrometric.csv', 'NL_daily_hydrometric.csv', 'NT_daily_hydrometric.csv', 'NU_daily_hydrometric.csv', 'ON_daily_hydrometric.csv', 'QC_daily_hydrometric.csv', 'SK_daily_hydrometric.csv']
#
#
# Concatenating all provincial daily hydrometric files into national file..
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=N;O=D.tmp'
#
#      0K .......... .......... ..........                        288K=0.1s
#
# 2022-01-23 20:54:20 (288 KB/s) - 'index.html@C=N;O=D.tmp' saved [31438]
#
# Removing index.html@C=N;O=D.tmp since it should be rejected.
#
# --2022-01-23 20:54:22--  https://dd.weather.gc.ca/hydrometric/csv/AB/daily/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:54:24--  https://dd.weather.gc.ca/hydrometric/csv/AB/daily/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=S;O=A.tmp'
#
#      0K .......... .......... ..........                        529K=0.06s
#
# 2022-01-23 20:54:25 (529 KB/s) - 'index.html@C=S;O=A.tmp' saved [31438]
#
# Removing index.html@C=S;O=A.tmp since it should be rejected.
#
# --2022-01-23 20:54:27--  https://dd.weather.gc.ca/hydrometric/csv/AB/daily/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 20:54:29--  https://dd.weather.gc.ca/hydrometric/csv/AB/daily/AB_daily_hydrometric.csv
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63388273 (60M) [text/csv]
# Saving to: 'AB_daily_hydrometric.csv'
#
#      0K .......... .......... .......... .......... ..........  0%  412K 2m30s
#     50K .......... .......... .......... .......... ..........  0% 1.03M 1m44s
#    100K .......... .......... .......... .......... ..........  0% 2.20M 79s
#    150K .......... .......... .......... .......... ..........  0% 2.11M 66s
#    200K .......... .......... .......... .......... ..........  0% 2.32M 58s
#    250K .......... .......... .......... .......... ..........  0% 2.17M 53s
#    300K .......... .......... .......... .......... ..........  0% 2.26M 49s
#    350K .......... .......... .......... .......... ..........  0% 2.33M 46s
#    400K .......... .......... .......... .......... ..........  0% 1.41M 46s
#    450K .......... .......... .......... .......... ..........  0% 1.96M 44s
#    500K .......... .......... .......... .......... ..........  0% 1.91M 43s
#    550K .......... .......... .......... .......... ..........  0% 2.13M 42s
#    600K .......... .......... .......... .......... ..........  1% 1.94M 41s
#    650K .......... .......... .......... .......... ..........  1% 2.79M 39s
#    700K .......... .......... .......... .......... ..........  1% 2.32M 38s
#    750K .......... .......... .......... .......... ..........  1% 2.53M 38s
#    800K .......... .......... .......... .......... ..........  1% 1.53M 38s
#    850K .......... .......... .......... .......... ..........  1% 2.46M 37s
#    900K .......... .......... .......... .......... ..........  1% 2.00M 36s
#    950K .......... .......... .......... .......... ..........  1% 1.66M 36s
#   1000K .......... .......... .......... .......... ..........  1% 2.13M 36s
#   1050K .......... .......... .......... .......... ..........  1% 1.98M 36s
#   1100K .......... .......... .......... .......... ..........  1% 1.85M 35s
#   1150K .......... .......... .......... .......... ..........  1% 2.10M 35s
#   1200K .......... .......... .......... .......... ..........  2% 1.45M 35s
#   1250K .......... .......... .......... .......... ..........  2% 1.92M 35s
#   1300K .......... .......... .......... .......... ..........  2% 2.25M 35s
#   1350K .......... .......... .......... .......... ..........  2% 2.35M 34s
#   1400K .......... .......... .......... .......... ..........  2% 1.74M 34s
#   1450K .......... .......... .......... .......... ..........  2% 2.46M 34s
#   1500K .......... .......... .......... .......... ..........  2% 2.48M 34s
#   1550K .......... .......... .......... .......... ..........  2% 2.18M 33s
#   1600K .......... .......... .......... .......... ..........  2% 1.32M 34s
#   1650K .......... .......... .......... .......... ..........  2% 2.60M 33s
#   1700K .......... .......... .......... .......... ..........  2% 2.55M 33s
#   1750K .......... .......... .......... .......... ..........  2% 2.25M 33s
#   1800K .......... .......... .......... .......... ..........  2% 1.82M 33s
#   1850K .......... .......... .......... .......... ..........  3% 1.95M 33s
#   1900K .......... .......... .......... .......... ..........  3% 1.80M 33s
#   1950K .......... .......... .......... .......... ..........  3% 2.17M 32s
#   2000K .......... .......... .......... .......... ..........  3% 1.47M 33s
#   2050K .......... .......... .......... .......... ..........  3% 2.38M 32s
#   2100K .......... .......... .......... .......... ..........  3% 2.60M 32s
#   2150K .......... .......... .......... .......... ..........  3% 2.38M 32s
#   2200K .......... .......... .......... .......... ..........  3% 2.01M 32s
#   2250K .......... .......... .......... .......... ..........  3% 1.88M 32s
#   2300K .......... .......... .......... .......... ..........  3% 1.94M 32s
#   2350K .......... .......... .......... .......... ..........  3% 1.80M 32s
#   2400K .......... .......... .......... .......... ..........  3% 1.63M 32s
#   2450K .......... .......... .......... .......... ..........  4% 1.91M 32s
#   2500K .......... .......... .......... .......... ..........  4% 2.13M 32s
#   2550K .......... .......... .......... .......... ..........  4% 2.41M 31s
#   2600K .......... .......... .......... .......... ..........  4% 2.23M 31s
#   2650K .......... .......... .......... .......... ..........  4% 2.39M 31s
#   2700K .......... .......... .......... .......... ..........  4% 2.04M 31s
#   2750K .......... .......... .......... .......... ..........  4% 2.25M 31s
#   2800K .......... .......... .......... .......... ..........  4% 1.71M 31s
#   2850K .......... .......... .......... .......... ..........  4% 2.56M 31s
#   2900K .......... .......... .......... .......... ..........  4% 2.55M 31s
#   2950K .......... .......... .......... .......... ..........  4% 2.32M 31s
#   3000K .......... .......... .......... .......... ..........  4% 3.17M 30s
#   3050K .......... .......... .......... .......... ..........  5% 2.32M 30s
#   3100K .......... .......... .......... .......... ..........  5% 3.44M 30s
#   3150K .......... .......... .......... .......... ..........  5% 3.05M 30s
#   3200K .......... .......... .......... .......... ..........  5% 1.86M 30s
#   3250K .......... .......... .......... .......... ..........  5% 2.60M 30s
#   3300K .......... .......... .......... .......... ..........  5% 2.35M 29s
#   3350K .......... .......... .......... .......... ..........  5% 3.08M 29s
#   3400K .......... .......... .......... .......... ..........  5% 2.18M 29s
#   3450K .......... .......... .......... .......... ..........  5% 2.95M 29s
#   3500K .......... .......... .......... .......... ..........  5% 2.72M 29s
#   3550K .......... .......... .......... .......... ..........  5% 2.32M 29s
#   3600K .......... .......... .......... .......... ..........  5% 2.76M 29s
#   3650K .......... .......... .......... .......... ..........  5% 2.37M 29s
#   3700K .......... .......... .......... .......... ..........  6% 2.82M 28s
#   3750K .......... .......... .......... .......... ..........  6% 3.27M 28s
#   3800K .......... .......... .......... .......... ..........  6% 3.85M 28s
#   3850K .......... .......... .......... .......... ..........  6% 3.60M 28s
#   3900K .......... .......... .......... .......... ..........  6% 4.09M 28s
#   3950K .......... .......... .......... .......... ..........  6% 4.03M 28s
#   4000K .......... .......... .......... .......... ..........  6% 2.51M 27s
#   4050K .......... .......... .......... .......... ..........  6% 3.85M 27s
#   4100K .......... .......... .......... .......... ..........  6% 3.96M 27s
#   4150K .......... .......... .......... .......... ..........  6% 2.89M 27s
#   4200K .......... .......... .......... .......... ..........  6% 3.73M 27s
#   4250K .......... .......... .......... .......... ..........  6% 3.27M 27s
#   4300K .......... .......... .......... .......... ..........  7% 2.98M 27s
#   4350K .......... .......... .......... .......... ..........  7% 3.65M 26s
#   4400K .......... .......... .......... .......... ..........  7% 2.58M 26s
#   4450K .......... .......... .......... .......... ..........  7% 4.92M 26s
#   4500K .......... .......... .......... .......... ..........  7% 2.98M 26s
#   4550K .......... .......... .......... .......... ..........  7% 3.83M 26s
#   4600K .......... .......... .......... .......... ..........  7% 3.65M 26s
#   4650K .......... .......... .......... .......... ..........  7% 3.54M 26s
#   4700K .......... .......... .......... .......... ..........  7% 4.09M 25s
#   4750K .......... .......... .......... .......... ..........  7% 4.32M 25s
#   4800K .......... .......... .......... .......... ..........  7% 2.43M 25s
#   4850K .......... .......... .......... .......... ..........  7% 2.54M 25s
#   4900K .......... .......... .......... .......... ..........  7% 3.95M 25s
#   4950K .......... .......... .......... .......... ..........  8% 5.00M 25s
#   5000K .......... .......... .......... .......... ..........  8% 3.45M 25s
#   5050K .......... .......... .......... .......... ..........  8% 3.18M 25s
#   5100K .......... .......... .......... .......... ..........  8% 2.66M 25s
#   5150K .......... .......... .......... .......... ..........  8% 2.78M 25s
#   5200K .......... .......... .......... .......... ..........  8% 2.34M 25s
#   5250K .......... .......... .......... .......... ..........  8% 4.21M 24s
#   5300K .......... .......... .......... .......... ..........  8% 3.11M 24s
#   5350K .......... .......... .......... .......... ..........  8% 3.44M 24s
#   5400K .......... .......... .......... .......... ..........  8% 3.37M 24s
#   5450K .......... .......... .......... .......... ..........  8% 3.48M 24s
#   5500K .......... .......... .......... .......... ..........  8% 3.76M 24s
#   5550K .......... .......... .......... .......... ..........  9% 4.32M 24s
#   5600K .......... .......... .......... .......... ..........  9% 2.82M 24s
#   5650K .......... .......... .......... .......... ..........  9% 3.71M 24s
#   5700K .......... .......... .......... .......... ..........  9% 4.10M 24s
#   5750K .......... .......... .......... .......... ..........  9% 4.15M 23s
#   5800K .......... .......... .......... .......... ..........  9% 4.22M 23s
#   5850K .......... .......... .......... .......... ..........  9% 4.10M 23s
#   5900K .......... .......... .......... .......... ..........  9% 3.17M 23s
#   5950K .......... .......... .......... .......... ..........  9% 4.93M 23s
#   6000K .......... .......... .......... .......... ..........  9% 2.78M 23s
#   6050K .......... .......... .......... .......... ..........  9% 3.06M 23s
#   6100K .......... .......... .......... .......... ..........  9% 2.61M 23s
#   6150K .......... .......... .......... .......... .......... 10% 2.70M 23s
#   6200K .......... .......... .......... .......... .......... 10% 3.93M 23s
#   6250K .......... .......... .......... .......... .......... 10% 3.05M 23s
#   6300K .......... .......... .......... .......... .......... 10% 3.20M 23s
#   6350K .......... .......... .......... .......... .......... 10% 2.69M 23s
#   6400K .......... .......... .......... .......... .......... 10% 1.84M 23s
#   6450K .......... .......... .......... .......... .......... 10% 3.10M 23s
#   6500K .......... .......... .......... .......... .......... 10% 2.61M 23s
#   6550K .......... .......... .......... .......... .......... 10% 3.03M 22s
#   6600K .......... .......... .......... .......... .......... 10% 3.36M 22s
#   6650K .......... .......... .......... .......... .......... 10% 2.41M 22s
#   6700K .......... .......... .......... .......... .......... 10% 2.73M 22s
#   6750K .......... .......... .......... .......... .......... 10% 2.49M 22s
#   6800K .......... .......... .......... .......... .......... 11% 1.98M 22s
#   6850K .......... .......... .......... .......... .......... 11% 2.87M 22s
#   6900K .......... .......... .......... .......... .......... 11% 2.39M 22s
#   6950K .......... .......... .......... .......... .......... 11% 3.37M 22s
#   7000K .......... .......... .......... .......... .......... 11% 3.32M 22s
# ...
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=D;O=D.tmp'
#
#      0K .......... .......                                      311K=0.06s
#
# 2022-01-23 21:02:09 (311 KB/s) - 'index.html@C=D;O=D.tmp' saved [17756]
#
# Removing index.html@C=D;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:11--  https://dd.weather.gc.ca/hydrometric/csv/NL/daily/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:02:13--  https://dd.weather.gc.ca/hydrometric/csv/NL/daily/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K .......... .....                                        286K=0.05s
#
# 2022-01-23 21:02:13 (286 KB/s) - 'index.html@C=S;O=D.tmp' saved [15923]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:15--  https://dd.weather.gc.ca/hydrometric/csv/NS/daily/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:02:17--  https://dd.weather.gc.ca/hydrometric/csv/NS/daily/?C=M;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5193 (5.1K) [text/html]
# Saving to: 'index.html@C=M;O=D.tmp'
#
#      0K .....                                                 100% 11.1M=0s
#
# 2022-01-23 21:02:17 (11.1 MB/s) - 'index.html@C=M;O=D.tmp' saved [5193/5193]
#
# Removing index.html@C=M;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:19--  https://dd.weather.gc.ca/hydrometric/csv/NS/daily/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:02:22--  https://dd.weather.gc.ca/hydrometric/csv/NS/hourly/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5114 (5.0K) [text/html]
# Saving to: 'index.html@C=N;O=A.tmp'
#
#      0K ....                                                  100% 34.3M=0s
#
# 2022-01-23 21:02:22 (34.3 MB/s) - 'index.html@C=N;O=A.tmp' saved [5114/5114]
#
# Removing index.html@C=N;O=A.tmp since it should be rejected.
#
# --2022-01-23 21:02:24--  https://dd.weather.gc.ca/hydrometric/csv/NS/hourly/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5114 (5.0K) [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K ....                                                  100% 46.4M=0s
#
# 2022-01-23 21:02:24 (46.4 MB/s) - 'index.html@C=S;O=D.tmp' saved [5114/5114]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:26--  https://dd.weather.gc.ca/hydrometric/csv/NT/daily/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:02:28--  https://dd.weather.gc.ca/hydrometric/csv/NT/daily/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K .......... ..                                          7.37M=0.002s
#
# 2022-01-23 21:02:29 (7.37 MB/s) - 'index.html@C=S;O=D.tmp' saved [12733]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:31--  https://dd.weather.gc.ca/hydrometric/csv/NT/hourly/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=N;O=A.tmp'
#
#      0K .......... .                                           16.5M=0.001s
#
# 2022-01-23 21:02:31 (16.5 MB/s) - 'index.html@C=N;O=A.tmp' saved [11729]
#
# Removing index.html@C=N;O=A.tmp since it should be rejected.
#
# --2022-01-23 21:02:33--  https://dd.weather.gc.ca/hydrometric/csv/NT/hourly/?C=M;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=M;O=D.tmp'
#
#      0K .......... .                                           13.1M=0.001s
#
# 2022-01-23 21:02:33 (13.1 MB/s) - 'index.html@C=M;O=D.tmp' saved [11729]
#
# Removing index.html@C=M;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:35--  https://dd.weather.gc.ca/hydrometric/csv/NT/hourly/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=D;O=D.tmp'
#
#      0K .......... .                                           6.24M=0.002s
#
# 2022-01-23 21:02:35 (6.24 MB/s) - 'index.html@C=D;O=D.tmp' saved [11729]
#
# Removing index.html@C=D;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:38--  https://dd.weather.gc.ca/hydrometric/csv/NU/daily/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:02:40--  https://dd.weather.gc.ca/hydrometric/csv/NU/daily/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3743 (3.7K) [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K ...                                                   100% 33.8M=0s
#
# 2022-01-23 21:02:40 (33.8 MB/s) - 'index.html@C=S;O=D.tmp' saved [3743/3743]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:42--  https://dd.weather.gc.ca/hydrometric/csv/ON/daily/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:02:44--  https://dd.weather.gc.ca/hydrometric/csv/ON/daily/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K .......... .......... .......... .......... ..........  437K
#     50K .......... .......... ..                               4.02M=0.1s
#
# 2022-01-23 21:02:45 (605 KB/s) - 'index.html@C=S;O=D.tmp' saved [74213]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:47--  https://dd.weather.gc.ca/hydrometric/csv/PE/hourly/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:02:49--  https://dd.weather.gc.ca/hydrometric/csv/PE/hourly/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1880 (1.8K) [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K .                                                     100% 18.3M=0s
#
# 2022-01-23 21:02:49 (18.3 MB/s) - 'index.html@C=S;O=D.tmp' saved [1880/1880]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:02:51--  https://dd.weather.gc.ca/hydrometric/csv/PE/hourly/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:02:53--  https://dd.weather.gc.ca/hydrometric/csv/QC/daily/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3163 (3.1K) [text/html]
# Saving to: 'index.html@C=N;O=A.tmp'
#
#      0K ...                                                   100% 20.7M=0s
#
# 2022-01-23 21:02:53 (20.7 MB/s) - 'index.html@C=N;O=A.tmp' saved [3163/3163]
#
# Removing index.html@C=N;O=A.tmp since it should be rejected.
#
# --2022-01-23 21:02:55--  https://dd.weather.gc.ca/hydrometric/csv/QC/daily/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:02:57--  https://dd.weather.gc.ca/hydrometric/csv/QC/hourly/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/html]
# Saving to: 'index.html@C=N;O=A.tmp'
#
#      0K ...                                                   100% 21.9M=0s
#
# 2022-01-23 21:02:58 (21.9 MB/s) - 'index.html@C=N;O=A.tmp' saved [3203/3203]
#
# Removing index.html@C=N;O=A.tmp since it should be rejected.
#
# --2022-01-23 21:03:00--  https://dd.weather.gc.ca/hydrometric/csv/QC/hourly/?C=M;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:03:02--  https://dd.weather.gc.ca/hydrometric/csv/QC/hourly/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3203 (3.1K) [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K ...                                                   100% 19.3M=0s
#
# 2022-01-23 21:03:02 (19.3 MB/s) - 'index.html@C=S;O=D.tmp' saved [3203/3203]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:03:04--  https://dd.weather.gc.ca/hydrometric/csv/QC/hourly/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:03:06--  https://dd.weather.gc.ca/hydrometric/csv/SK/daily/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=N;O=A.tmp'
#
#      0K .......... .......... .                                 400K=0.05s
#
# 2022-01-23 21:03:06 (400 KB/s) - 'index.html@C=N;O=A.tmp' saved [22303]
#
# Removing index.html@C=N;O=A.tmp since it should be rejected.
#
# --2022-01-23 21:03:08--  https://dd.weather.gc.ca/hydrometric/csv/SK/daily/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K .......... .......... .                                 371K=0.06s
#
# 2022-01-23 21:03:09 (371 KB/s) - 'index.html@C=S;O=D.tmp' saved [22303]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:03:11--  https://dd.weather.gc.ca/hydrometric/csv/SK/hourly/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=N;O=A.tmp'
#
#      0K .......... .......... ..                                402K=0.05s
#
# 2022-01-23 21:03:11 (402 KB/s) - 'index.html@C=N;O=A.tmp' saved [22607]
#
# Removing index.html@C=N;O=A.tmp since it should be rejected.
#
# --2022-01-23 21:03:13--  https://dd.weather.gc.ca/hydrometric/csv/SK/hourly/?C=M;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=M;O=D.tmp'
#
#      0K .......... .......... ..                                392K=0.06s
#
# 2022-01-23 21:03:13 (392 KB/s) - 'index.html@C=M;O=D.tmp' saved [22607]
#
# Removing index.html@C=M;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:03:15--  https://dd.weather.gc.ca/hydrometric/csv/SK/hourly/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=D;O=D.tmp'
#
#      0K .......... .......... ..                                393K=0.06s
#
# 2022-01-23 21:03:16 (393 KB/s) - 'index.html@C=D;O=D.tmp' saved [22607]
#
# Removing index.html@C=D;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:03:18--  https://dd.weather.gc.ca/hydrometric/csv/YT/daily/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:03:20--  https://dd.weather.gc.ca/hydrometric/csv/YT/daily/?C=M;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=M;O=D.tmp'
#
#      0K .........                                              25.9M=0s
#
# 2022-01-23 21:03:20 (25.9 MB/s) - 'index.html@C=M;O=D.tmp' saved [9978]
#
# Removing index.html@C=M;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:03:22--  https://dd.weather.gc.ca/hydrometric/csv/YT/daily/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K .........                                              6.62M=0.001s
#
# 2022-01-23 21:03:22 (6.62 MB/s) - 'index.html@C=S;O=D.tmp' saved [9978]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:03:24--  https://dd.weather.gc.ca/hydrometric/csv/YT/daily/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:03:27--  https://dd.weather.gc.ca/hydrometric/csv/YT/hourly/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=N;O=A.tmp'
#
#      0K .........                                              4.94M=0.002s
#
# 2022-01-23 21:03:27 (4.94 MB/s) - 'index.html@C=N;O=A.tmp' saved [9377]
#
# Removing index.html@C=N;O=A.tmp since it should be rejected.
#
# --2022-01-23 21:03:29--  https://dd.weather.gc.ca/hydrometric/csv/YT/hourly/?C=M;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# Unable to establish SSL connection.
# --2022-01-23 21:03:31--  https://dd.weather.gc.ca/hydrometric/csv/YT/hourly/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=S;O=D.tmp'
#
#      0K .........                                              6.72M=0.001s
#
# 2022-01-23 21:03:31 (6.72 MB/s) - 'index.html@C=S;O=D.tmp' saved [9377]
#
# Removing index.html@C=S;O=D.tmp since it should be rejected.
#
# --2022-01-23 21:03:33--  https://dd.weather.gc.ca/hydrometric/csv/YT/hourly/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: 'index.html@C=D;O=D.tmp'
#
#      0K .........                                              1.81M=0.005s
#
# 2022-01-23 21:03:33 (1.81 MB/s) - 'index.html@C=D;O=D.tmp' saved [9377]
#
# Removing index.html@C=D;O=D.tmp since it should be rejected.
#
# FINISHED --2022-01-23 21:03:33--
# Total wall clock time: 12m 50s
# Downloaded: 181 files, 573M in 3m 17s (2.90 MB/s)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11125080 entries, 0 to 11125079
# Data columns (total 9 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   ID                       object
#  1   DATE                     object
#  2   WATER_LEVEL_M            float32
#  3   FLOWRATE_CMS             float32
#  4   PROV_TERR                object
#  5   LATITUDE                 float32
#  6   LONGITUDE                float32
#  7   DRAINAGE_AREA_GROSS_KM2  float32
#  8   STATION                  object
# dtypes: float32(5), object(4)
# memory usage: 894.6+ MB

# %% [markdown]
# # Part III: Create and Clean Master DataFrame

# %% [markdown]
# ## Create or Clean Master DataFrame (CAN_daily_hydrometric_master.csv)
#
# - Read in the MASTER df using Dask
# - Concat both DataFrames on the DATE column. This adds the newest dates to the MASTER df.
# - Convert all numeric values to float32 and convert DATE column to datetime64[ns, utc] format.
# - Compare the lengths of the DAILY df and the MASTER df
# - Export the new MASTER df to .csv and overwrite the old MASTER .csv file
#
# **Notes:**
#
# * *The .csv file will continue to grow and is easiest to process using Dask for in-memory processing
#   as processing memory above 16GB can be selected*
#
# * *To save time and money, multiple VMs (Virtual Machine) such as Amazon EC2 or Microsoft Azure VM
#   are the fastest method to plug into big computing power. Only consider this for very large real-time
#   datasets as it becomes pricey depending on the size of the datasets (GB, TB, PB, etc.)*
#
# * *Runtime ~ 6 mins*

# %%
import os.path

# If Master file exists in filepath..
if os.path.isfile(r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily/og/CAN_daily_hydrometric_master.parquet'):
    
    print("File exists! Merge Daily DataFrame with Master DataFrame..")
    
    os.chdir(r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily/og/')

    f = r'CAN_daily_hydrometric_master.parquet'

    # Import the new MASTER.csv as a DataFrmae and follow same cleaning process as above.
    df_master = pd.read_parquet(f, engine='pyarrow') 

    # Replace all NaN (null and N/A) numeric columns with np.NaN value
    float_cols_na = ['WATER_LEVEL_M', 
                     'FLOWRATE_CMS', 
                     'LATITUDE', 
                     'LONGITUDE', 
                     'DRAINAGE_AREA_GROSS_KM2']
    
    df_master[float_cols_na] = df_master[float_cols_na].replace({'NaN': np.nan})

    # Drop all null rows
    df_master.dropna(axis=0, inplace=True)

    print('Merge master and daily DataFrames. Add newest DATE rows to the master DataFrame..')
    df_final = pd.concat([df_master, df_daily], ignore_index=True)
    df_final.info()
    
    df_final['DATE'] = pd.to_datetime(df_final['DATE'], errors='coerce', utc=True)
    
    keep_cols = ['ID',
                'DATE',
                'WATER_LEVEL_M',
                'FLOWRATE_CMS',
                'PROV_TERR',
                'LATITUDE',
                'LONGITUDE',
                'DRAINAGE_AREA_GROSS_KM2',
                'STATION']
    
    # Drop unneeded columns
    df_final.drop(columns=[col for col in df_final if col not in keep_cols], inplace=True)
        
    df_final.reset_index(inplace=True, drop=True)
    df_final.info()
    
    print('Export Master DataFrame to .parq format..')
    
    master_csv_file = r'CAN_daily_hydrometric_master.parquet'
    df_final.to_parquet(master_csv_file)
    
    len_df_daily = len(df_daily)
    len_df_final = len(df_final)

    print(f'Daily DataFrame length: {len_df_daily} \n')
    print(f'Master DataFrame length: {len_df_final} \n')
    
else:  
        
    print('CAN_daily_hydrometric_master file does not exist! Create Master .csv file...')
    
    # Replace all NaN (null and N/A) numeric columns with np.NaN value
    float_cols = ["FLOWRATE_CMS", 
                  "WATER_LEVEL_M", 
                  "DRAINAGE_AREA_GROSS_KM2", 
                  "LATITUDE", 
                  "LONGITUDE"]

    df_daily[float_cols] = df_daily[float_cols].replace({'NaN': np.nan})

    # Drop all null rows
    df_daily.dropna(axis=0, inplace=True)
    
    keep_cols = ['ID',
                'DATE',
                'WATER_LEVEL_M',
                'FLOWRATE_CMS',
                'PROV_TERR',
                'LATITUDE',
                'LONGITUDE',
                'DRAINAGE_AREA_GROSS_KM2',
                'STATION']
    
    df_daily.drop(columns=[col for col in df_daily if col not in keep_cols], inplace=True)
    
    df_daily.reset_index(inplace=True, drop=True)
    df_daily.info()
        
    print("Master DataFrame and master .csv file created!")
    
    # Export DataFrame to .csv (named master)
    os.chdir(r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily/og')

    # Create new MASTER.csv file from DAILY DataFrame
    master_csv_file = r"CAN_daily_hydrometric_master.parquet"
    df_daily.to_parquet(master_csv_file, engine='pyarrow')
# Out:
# File exists! Merge Daily DataFrame with Master DataFrame..
# Merge master and daily DataFrames. Add newest DATE rows to the master DataFrame..
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34367608 entries, 0 to 34367607
# Data columns (total 9 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   ID                       object
#  1   DATE                     object
#  2   WATER_LEVEL_M            float32
#  3   FLOWRATE_CMS             float32
#  4   PROV_TERR                object
#  5   LATITUDE                 float32
#  6   LONGITUDE                float32
#  7   DRAINAGE_AREA_GROSS_KM2  float32
#  8   STATION                  object
# dtypes: float32(5), object(4)
# memory usage: 1.7+ GB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34367608 entries, 0 to 34367607
# Data columns (total 9 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   ID                       object
#  1   DATE                     datetime64[ns, UTC]
#  2   WATER_LEVEL_M            float32
#  3   FLOWRATE_CMS             float32
#  4   PROV_TERR                object
#  5   LATITUDE                 float32
#  6   LONGITUDE                float32
#  7   DRAINAGE_AREA_GROSS_KM2  float32
#  8   STATION                  object
# dtypes: datetime64[ns, UTC](1), float32(5), object(3)
# memory usage: 1.7+ GB
# Export Master DataFrame to .csv format..
# Daily DataFrame length: 11125080
# Master DataFrame length: 34367608
#         ID                      DATE  WATER_LEVEL_M  FLOWRATE_CMS PROV_TERR  \
# 0  07EA005 2021-12-19 08:00:00+00:00          1.777        70.600        BC
# 1  07EA005 2021-12-19 08:05:00+00:00          1.777        70.600        BC
# 2  07EA005 2021-12-19 08:10:00+00:00          1.776        70.600        BC
# 3  07EA005 2021-12-19 08:15:00+00:00          1.777        70.600        BC
# 4  07EA005 2021-12-19 08:20:00+00:00          1.775        70.600        BC
#
#    LATITUDE  LONGITUDE  DRAINAGE_AREA_GROSS_KM2  \
# 0    57.126   -125.250               15,600.000
# 1    57.126   -125.250               15,600.000
# 2    57.126   -125.250               15,600.000
# 3    57.126   -125.250               15,600.000
# 4    57.126   -125.250               15,600.000
#
#                                    STATION
# 0  BC07EA005_FINLAY_RIVER_ABOVE_AKIE_RIVER
# 1  BC07EA005_FINLAY_RIVER_ABOVE_AKIE_RIVER
# 2  BC07EA005_FINLAY_RIVER_ABOVE_AKIE_RIVER
# 3  BC07EA005_FINLAY_RIVER_ABOVE_AKIE_RIVER
# 4  BC07EA005_FINLAY_RIVER_ABOVE_AKIE_RIVER

# %% [markdown]
# ## Delete individual provincial .csv files in CanadaDaily directory

# %%
import os
import glob
import time

# Delete all provincial .csv files
for CleanUp in glob.glob(r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily/*.*'):
    print(f'Files in CanadaDaily folder: {CleanUp}')
    
    if CleanUp.endswith('.csv'):    
        os.remove(CleanUp)
# Out:
# Files in CanadaDaily folder: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily\AB_daily_hydrometric.csv
# Files in CanadaDaily folder: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily\BC_daily_hydrometric.csv
# Files in CanadaDaily folder: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily\NL_daily_hydrometric.csv
# Files in CanadaDaily folder: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily\NT_daily_hydrometric.csv
# Files in CanadaDaily folder: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily\NU_daily_hydrometric.csv
# Files in CanadaDaily folder: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily\ON_daily_hydrometric.csv
# Files in CanadaDaily folder: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily\QC_daily_hydrometric.csv
# Files in CanadaDaily folder: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily\SK_daily_hydrometric.csv

# %% [markdown]
# ## List of final files
#
# **Files:**
#
# * **Canadian Daily Hydrometric Stations: CAN_daily_hydrometric.csv**
#
#    * *Location: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/CanadaDaily*
#
#
# * **Canadian Daily Hydrometric Stations (MASTER): CAN_daily_hydrometric.master.csv**
#
#    * *Location: C:/Users/pdudar/anaconda3/projects/CanadaWatQual/CanadaDaily/og*

# %% [markdown]
# # Part IV: Plotly Chart generation
#
# ## Create Hydrometric Daily Plotly Time Series Charts
#
# * *Create .html charts for all Hydrometric Stations across Canada*
# * *Discharge/Flow Rate (cms) is displayed on LEFT side of chart*
# * *Water Level (m) is displayed on RIGHT side of chart*

# %%
master_file_path = r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/CanadaDaily/og/CAN_daily_hydrometric_master.parquet'

if os.path.isfile(master_file_path):
    
    os.chdir(r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/plotly')

    f = r'CAN_daily_hydrometric_master.parquet'
    df_master = pd.read_parquet(f, engine='fastparquet')

    d_plotly = dict(tuple(df_master.groupby(['STATION'])))

    k = 1
    l = 0
    len_stations = len(df_master.STATION.unique())

    convert = float(3.0 * 0.0167) # Seconds to minutes
    chart_time = convert * len_stations

    print(f'Number of charts to create: {len_stations}')
    print(f'Chart processing time: {chart_time} minutes')

    ##### ----- Make Plotly Time Series Charts ----- #####
    from plotly import __version__ 
    import cufflinks as cf 
    from plotly.offline import init_notebook_mode, iplot 

    import plotly.graph_objects as go
    import plotly.express as px
    from plotly.subplots import make_subplots

    # Create figure with secondary y-axis
    fig = make_subplots(specs=[[{"secondary_y": True}]])

    # to get the connection 
    init_notebook_mode(connected = True) 
 
    cf.go_offline 

    print('Creating Plotly charts.. \n')

    d_plotly = dict(tuple(df_master.groupby(['STATION'])))

    k = 1
    l = 0
    len_stations = len(df_master.STATION.unique())

    start = datetime.datetime.now()

    for key in d_plotly.keys():
        d_plotly[key] = df_master[:][df_master.STATION == key]
        df_export_plotly = d_plotly[key]

        # Create figure with secondary y-axis
        subfig = make_subplots(specs=[[{"secondary_y": True}]])

        # Generate a Plotly TimeSeries chart for each monitoring station
        fig = px.line(df_export_plotly, 
                        x =  'DATE',
                        y = 'FLOWRATE_CMS',
                        title=key + ': ' + 'Canada Hydrometric Flow Data - Time Series Info',
                        hover_name = 'STATION', 
                        hover_data = ['FLOWRATE_CMS',
                                      'LATITUDE',
                                      'LONGITUDE',
                                      'DRAINAGE_AREA_GROSS_KM2']         
                        )

        fig2 = px.line(df_export_plotly, 
                        x='DATE',
                        y='WATER_LEVEL_M', 
                        hover_name = 'STATION', 
                        hover_data = ['WATER_LEVEL_M',
                                      'LATITUDE',
                                      'LONGITUDE',
                                      'DRAINAGE_AREA_GROSS_KM2']
                                   
                        )
           
        fig2.update_traces(yaxis="y2")

        subfig.add_traces(fig.data + fig2.data)
        subfig.layout.xaxis.title="Date"
        subfig.layout.yaxis.title="Flowrate (cms)"
        subfig.layout.yaxis2.type="linear"
        subfig.layout.yaxis2.title="Water Level (m)"

        # recoloring is necessary otherwise lines from fig und fig2 would share each color
        # e.g. Linear-, Log- = blue; Linear+, Log+ = red... we don't want this
        subfig.for_each_trace(lambda t: t.update(line=dict(color=t.marker.color))) 

        # Add figure title
        subfig.update_layout(
            title_text= key + ': ' + 'Canada Hydrometric Flow Data - Time Series Info'
        )

        # Set y-axes titles
        subfig.update_yaxes(title_text="<b>Flow Rate (cms)</b>", secondary_y=False)
        subfig.update_yaxes(title_text="<b>Water Level (m)</b>", secondary_y=True)

        subfig.update_xaxes(
            rangeslider_visible=True,
            rangeselector=dict(
                buttons=list([
                    dict(count=1, label="1DAY", step="day", stepmode="backward"),
                    dict(count=7, label="1WK", step="day", stepmode="backward"),
                    dict(count=14, label="2WK", step="day", stepmode="backward"),
                    dict(count=1, label="1MNTH", step="month", stepmode="backward"),
                    dict(count=3, label="3MNTH", step="month", stepmode="backward"),
                    dict(count=6, label="6MNTH", step="month", stepmode="backward"),
                    dict(count=1, label="YTD", step="year", stepmode="todate"),
                    dict(count=1, label="1YR", step="year", stepmode="backward"),
                    dict(step="all")
                ])
            )
        )
        
        # Chart options

        subfig.update_layout(plot_bgcolor = "RGB(45,45,48)")  	#2d2d30
        subfig.update_layout(paper_bgcolor = "RGB(37,37,38)") #252526
        subfig.update_layout(
        font_color="RGB(131,148,150)",  	#839496
        title_font_color="RGB(131,148,150)",  	#839496
        legend_title_font_color="RGB(131,148,150)") #839496

        # Append station names to .html files
        subfig.write_html(key + '.html', include_plotlyjs='cdn')

        print('{} seconds: Completed {} plotly charts!'.format((datetime.datetime.now() - start).seconds, k))
        if l == len_stations:
            break
        else:
            l+=1

        k+=1

    print('Plotly charts completed! Charts saved in following '
        'directory: /CanadaWatQual/Hydro/plotly')
    
else:
    
    print('Error. No file in master.csv directory.')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18812/2335736122.py in <module>
#       6
#       7     f = r'CAN_daily_hydrometric_master.parquet'
# ----> 8     df_master = pd.read_parquet(f, engine='fastparquet')
#       9
#      10     d_plotly = dict(tuple(df_master.groupby(['STATION'])))
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     498         storage_options=storage_options,
#     499         use_nullable_dtypes=use_nullable_dtypes,
# --> 500         **kwargs,
#     501     )
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, storage_options, **kwargs)
#     338             # this branch is used for example when reading from non-fsspec URLs
#     339             handles = get_handle(
# --> 340                 path, "rb", is_text=False, storage_options=storage_options
#     341             )
#     342             path = handles.handle
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'CAN_daily_hydrometric_master.parquet'

# %% [markdown]
# ## Compress all Plotly.html files to .zip folder

# %%
os.chdir(r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/plotly')

# Compress all Plotly.html files to .zip folder
import os
import glob
import zipfile
try:
    import zlib
    mode = zipfile.ZIP_DEFLATED
except:
    mode = zipfile.ZIP_STORED

file_path = r'/CanadaDailyHydrometricPlotly'
zipfile_path = r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/plotly/daily_hydro_plotly_html.zip'
plotly_zip = zipfile.ZipFile(zipfile_path, 'w', mode)

for folder, subfolders, files in os.walk(file_path):
    for file in files:
        if file.endswith('*.html'):
            # Write all .html files to .zip file
            plotly_zip.write(os.path.join(folder, file), compress_type=mode)

# Close the .zip file and end process                             
plotly_zip.close()

# Delete all leftover .html files in /CanadaDailyHydrometricPlotly folder
folder = r'C:/Users/pdudar/anaconda3/projects/CanadaWatQual/Hydro/plotly'
for CleanUp in glob.glob(folder):
    print(CleanUp)

    if CleanUp.endswith('*.html'):    
        os.remove(CleanUp)
        
print('Plotly Hydrometric charts zipped to .zip file!')
